# %% [markdown]
# <a href="https://colab.research.google.com/github/EstebanFTellezR/Modelaci-n-y-aja/blob/main/Parra_Tutorial_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 7rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 🧮 Exploring DataFrames 🧐</h1>

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;">  1)  What's Pandas?   <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a> </h1> </h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">1.1) Pandas is :<h2/>
# <p style="font-size: 2rem">Pandas is an open source Python library that provides high-performance, easy-to-use data structures and data analysis tools. It is widely used in the world of data analysis and data science.</p>
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">1.2) How to import it:<h2/>

# %%
# %%time
# If you want to import pandas inside your conda environment, you can use the following command:
! conda install pandas # use conda package manager to install pandas
# OR you can use:
! pip install pandas # use pip package manager to install pandas
# Out:
# /bin/bash: line 1: conda: command not found
# ...
# CPU times: user 72.7 ms, sys: 13.6 ms, total: 86.3 ms
# Wall time: 7.99 s

# %%
# %%time
import pandas as pd # call pandas library with an alias 'pd' (common alias for pandas)
# Out:
# CPU times: user 553 ms, sys: 77.9 ms, total: 631 ms
# Wall time: 1.21 s

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 2)  Basic data structures   <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a> </h1></h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">2.1) Series: <h2/>
#
# # Mathematical Definition of a Pandas Series
#
# A **Pandas Series** can be defined as a one-dimensional array-like structure, indexed and labeled, represented as:
#
# $$
# S = \begin{pmatrix}
# s_1 \\
# s_2 \\
# \vdots \\
# s_n \\
# \end{pmatrix}
# $$
#
# where $S$ is the Series, $n$ is the number of elements, and each $s_i$ represents the value at position $i$. Additionally:
#
#
# -     The elements are indexed by a set of indices $I = \{i_1, i_2, \dots, i_n\}$.
# -     Each element $s_i$ can belong to any data type (e.g., numeric, string, boolean).
#
#
# **Vector Interpretation:** If all elements of the Series are numeric, it can be viewed as a vector in an $n$-dimensional space:
#
# $$
# \mathbf{S} =
# \begin{pmatrix}
# s_1 \\
# s_2 \\
# \vdots \\
# s_n \\
# \end{pmatrix}
# \quad \text{where } \mathbf{S} \in \mathbb{R}^n
# $$
#
# In this context, the Series $S$ is a single column vector in the vector space $\mathbb{R}^n$.

# %%
# %%time

# Creating a Series from a list
data = [10, 20, 30, 40, 50]      # Creates a list named 'data' with five integer values.
series = pd.Series(data)         # Converts the 'data' list into a Pandas Series, which is like a column of data in a table.
print(series)                    # Prints the Pandas Series to the console, displaying the data and their corresponding indices.
# Out:
# 0    10
#
# 1    20
#
# 2    30
#
# 3    40
#
# 4    50
#
# dtype: int64
#
# CPU times: user 418 μs, sys: 76 μs, total: 494 μs
#
# Wall time: 494 μs

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">2.2) Dataframes: <h2/>
#
#
# # Mathematical Definition of a DataFrame
#
# A **DataFrame** can be defined as a two-dimensional matrix with indices and labels, represented as:
#
#
# $$DF =
# \begin{pmatrix}
# x_{11} & x_{12} & \cdots & x_{1n} \\
# x_{21} & x_{22} & \cdots & x_{2n} \\
# \vdots & \vdots & \ddots & \vdots \\
# x_{m1} & x_{m2} & \cdots & x_{mn} \\
# \end{pmatrix}
# $$
#
# where \(DF\) is the DataFrame, \(m\) is the number of rows, \(n\) is the number of columns, and each $(x_{ij})$ represents the value in row \(i\) and column \(j\). Additionally:
#
# - The rows are indexed by a set of indices $$I = \{i_1, i_2, \dots, i_m\}$$
# - The columns are labeled by a set of labels $$C = \{c_1, c_2, \dots, c_n\}$$
#
# **Columns as Vectors:** Each column of the DataFrame can be viewed as a vector in an \(m\)-dimensional space:
#
# $$
# \mathbf{c_j} =
# \begin{pmatrix}
# x_{1j} \\
# x_{2j} \\
# \vdots \\
# x_{mj} \\
# \end{pmatrix}
# \quad \text{for } j = 1, 2, \dots, n
# $$
#
# **Vector Space:** If all columns of the DataFrame are numeric, the rows can be interpreted as points in an \(n\)-dimensional vector space $\mathbb{R}^n$.
#    The entire DataFrame can be considered as a set of \(m\) points in $\mathbb{R}^n$

# %%
# %%time
# Creating a DataFrame from a dictionary
dd = {'Name': ['John', 'Anna', 'Peter'],  # Creates a dictionary with keys 'Name', 'Age', and 'City', each associated with a list of values
      'Age': [28, 24, 22],               # 'Name' has a list of names, 'Age' has a list of ages
      'City': ['New York', 'Los Angeles', 'Chicago']}  # 'City' has a list of cities

df1 = pd.DataFrame(dd)  # Converts the dictionary 'dd' into a DataFrame (a table-like data structure in pandas)

df1  # Displays the DataFrame, showing the 'Name', 'Age', and 'City' columns with their respective values
# Out:
# CPU times: user 511 μs, sys: 93 μs, total: 604 μs
#
# Wall time: 588 μs
#     Name  Age         City
# 0   John   28     New York
# 1   Anna   24  Los Angeles
# 2  Peter   22      Chicago

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 3) Data ingestion  <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a> <a href="#cita3" target="_blank" style="color:#b5ff46; font-size:2.5rem">[3]</a> </h1>
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">3.1) From .csv files (Comma Separated Values): <h2/>

# %%
# %%time
df_csv = pd.read_csv('./Data/teams.csv')  # Reads the CSV file located at './Data/teams.csv' into a DataFrame called df_csv
df_csv  # Displays the content of df_csv
# Out:
# CPU times: user 9.39 ms, sys: 0 ns, total: 9.39 ms
#
# Wall time: 8.79 ms
#                    code                        team team_gender  \
# 0     ARCMTEAM3---CHN01  People's Republic of China           M
# 1     ARCMTEAM3---COL01                    Colombia           M
# 2     ARCMTEAM3---FRA01                      France           M
# 3     ARCMTEAM3---GBR01               Great Britain           M
# 4     ARCMTEAM3---IND01                       India           M
# ...                 ...                         ...         ...
# 1693  WPOWTEAM7---GRE01                      Greece           W
# 1694  WPOWTEAM7---HUN01                     Hungary           W
# 1695  WPOWTEAM7---ITA01                       Italy           W
# 1696  WPOWTEAM7---NED01                 Netherlands           W
# 1697  WPOWTEAM7---USA01    United States of America           W
#
#             country                country_full country_code  discipline  \
# ...

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">3.2) From .xlsx files (Excel): <h2/>

# %%
# %%time
df_excel = pd.read_excel('./Data/equipos.xlsx')  # Reads an Excel file located at './Data/equipos.xlsx' and stores it in the variable 'df_excel'
df_excel  # Displays the content of the 'df_excel' variable, which is the DataFrame read from the Excel file
# Out:
# CPU times: user 231 ms, sys: 2.86 ms, total: 234 ms
#
# Wall time: 233 ms
#                    code                        team team_gender  \
# 0     ARCMTEAM3---CHN01  People's Republic of China           M
# 1     ARCMTEAM3---COL01                    Colombia           M
# 2     ARCMTEAM3---FRA01                      France           M
# 3     ARCMTEAM3---GBR01               Great Britain           M
# 4     ARCMTEAM3---IND01                       India           M
# ...                 ...                         ...         ...
# 1693  WPOWTEAM7---GRE01                      Greece           W
# 1694  WPOWTEAM7---HUN01                     Hungary           W
# 1695  WPOWTEAM7---ITA01                       Italy           W
# 1696  WPOWTEAM7---NED01                 Netherlands           W
# 1697  WPOWTEAM7---USA01    United States of America           W
#
#             country                country_full country_code  discipline  \
# ...

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">3.3) From pd dictionary: <h2/>

# %%
# %%time
data_dict = {'Nombre': ['Ana', 'Juan'], 'Edad': [28, 24]}  # Creates a dictionary with two keys: 'Nombre' and 'Edad'.
# 'Nombre' has a list of names
# and 'Edad' has a list of ages associated with the names.

df_dict = pd.DataFrame(data_dict)  # Converts the dictionary 'data_dict' into a pandas DataFrame.
df_dict  # Displays the content of the 'df_dict' DataFrame, showing the 'Nombre' and 'Edad' columns with their respective values.
# Out:
# CPU times: user 251 μs, sys: 40 μs, total: 291 μs
#
# Wall time: 295 μs
#   Nombre  Edad
# 0    Ana    28
# 1   Juan    24

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 4) Exploratory Data Analysis (EDA)  <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a> </h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">4.1) Methods .head() && .tail() :<h2/>

# %%
# %%time
print(df_csv.head(10))  # Prints the first 10 records of the DataFrame
print(df_csv.tail(10))  # Prints the last 10 records of the DataFrame
# Out:
#                 code                        team team_gender        country  \
#
# 0  ARCMTEAM3---CHN01  People's Republic of China           M          China
#
# 1  ARCMTEAM3---COL01                    Colombia           M       Colombia
#
# 2  ARCMTEAM3---FRA01                      France           M         France
#
# 3  ARCMTEAM3---GBR01               Great Britain           M  Great Britain
#
# 4  ARCMTEAM3---IND01                       India           M          India
#
# 5  ARCMTEAM3---ITA01                       Italy           M          Italy
#
# 6  ARCMTEAM3---JPN01                       Japan           M          Japan
#
# 7  ARCMTEAM3---KAZ01                  Kazakhstan           M     Kazakhstan
#
# 8  ARCMTEAM3---KOR01           Republic of Korea           M          Korea
#
# 9  ARCMTEAM3---MEX01                      Mexico           M         Mexico
#
#
#
#                  country_full country_code discipline disciplines_code  \
#
# ...

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">4.2) Method .info() :<h2/>

# %%
# %%time
print(df_csv.info()) # Displays a summary of the DataFrame, including the number of non-null values in each column and the data type of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 1698 entries, 0 to 1697
#
# Data columns (total 15 columns):
#
#  #   Column            Non-Null Count  Dtype
#
# ---  ------            --------------  -----
#
#  0   code              1698 non-null   object
#
#  1   team              1698 non-null   object
#
#  2   team_gender       1698 non-null   object
#
#  3   country           1698 non-null   object
#
#  4   country_full      1698 non-null   object
#
#  5   country_code      1698 non-null   object
#
#  6   discipline        1698 non-null   object
#
#  7   disciplines_code  1698 non-null   object
#
#  8   events            1377 non-null   object
#
#  9   athletes          1695 non-null   object
#
#  10  coaches           246 non-null    object
#
#  11  athletes_codes    1695 non-null   object
#
#  12  num_athletes      1695 non-null   float64
#
#  13  coaches_codes     246 non-null    object
#
#  14  num_coaches       246 non-null    float64
#
# ...

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">4.3) Method .describe() :<h2/>

# %%
# %%time
print(df_csv.describe()) # Displays statistical summaries of the NUMERICAL columns in the DataFrame
# Out:
#        num_athletes  num_coaches
#
# count   1695.000000   246.000000
#
# mean       4.600590     4.365854
#
# std        3.888545     2.263349
#
# min        2.000000     1.000000
#
# 25%        2.000000     2.250000
#
# 50%        4.000000     4.000000
#
# 75%        4.000000     6.000000
#
# max       22.000000    12.000000
#
# CPU times: user 2.08 ms, sys: 3.54 ms, total: 5.63 ms
#
# Wall time: 4.89 ms

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 5) Data selection and filtering <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a>  </h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">5.1) Column selection :<h2/>

# %%
# %%time
df_csv_selected = df_csv[['disciplines_code', 'num_athletes']]  #Select the number of disciplines_code and num_athletes columns from the DataFrame
df_csv_selected # Display the selected columns
# Out:
# CPU times: user 637 μs, sys: 0 ns, total: 637 μs
#
# Wall time: 622 μs
#      disciplines_code  num_athletes
# 0                 ARC           3.0
# 1                 ARC           3.0
# 2                 ARC           3.0
# 3                 ARC           3.0
# 4                 ARC           3.0
# ...               ...           ...
# 1693              WPO          13.0
# 1694              WPO          13.0
# 1695              WPO          13.0
# 1696              WPO          13.0
# 1697              WPO          13.0
#
# [1698 rows x 2 columns]

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">5.2) Filter by conditions : <h2/>

# %%
# %%time
print(df_csv_selected[df_csv_selected['num_athletes'] > 15]) # Prints the rows where the number of athletes is greater than 10
# Out:
#     disciplines_code  num_athletes
#
# 481              FBL          18.0
#
# 482              FBL          19.0
#
# 483              FBL          19.0
#
# 484              FBL          22.0
#
# 485              FBL          21.0
#
# ..               ...           ...
#
# 638              HOC          18.0
#
# 639              HOC          16.0
#
# 640              HOC          17.0
#
# 641              HOC          17.0
#
# 642              HOC          16.0
#
#
#
# [61 rows x 2 columns]
#
# CPU times: user 2.43 ms, sys: 0 ns, total: 2.43 ms
#
# Wall time: 2.35 ms

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">5.3) Methods .loc &&. iloc :<h2/>

# %%
# %%time

print(f'LOC METHOD >>>>> \n{df_csv.loc[df_csv['num_athletes'] > 20, ['team', 'country', 'num_athletes']]}') # Select rows where num_athletes > 20 and only display the columns 'team', 'country', and 'num_athletes'.
print(f'ILOC METHOD >>>>> \n{df_csv.iloc[0:5, [1, 3, 6]]}') # Selects the first 5 rows and only displays the columns in positions 1, 3, and 6.
# Out:
# LOC METHOD >>>>>
#
#            team     country  num_athletes
#
# 484       Spain       Spain          22.0
#
# 485      France      France          21.0
#
# 489       Japan       Japan          21.0
#
# 496  Uzbekistan  Uzbekistan          21.0
#
# 498      Brazil      Brazil          22.0
#
# 501       Spain       Spain          22.0
#
# 504       Japan       Japan          22.0
#
# ILOC METHOD >>>>>
#
#                          team        country discipline
#
# 0  People's Republic of China          China    Archery
#
# 1                    Colombia       Colombia    Archery
#
# 2                      France         France    Archery
#
# 3               Great Britain  Great Britain    Archery
#
# 4                       India          India    Archery
#
# CPU times: user 3.19 ms, sys: 0 ns, total: 3.19 ms
#
# Wall time: 3.08 ms

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 6) Handling of missing values <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a>  </h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">6.1) Identification of null values :<h2/>

# %%
# %%time
df_csv.isnull().sum() # Returns the number of null values in each column
# Out:
# CPU times: user 1.59 ms, sys: 0 ns, total: 1.59 ms
#
# Wall time: 1.43 ms
# code                   0
# team                   0
# team_gender            0
# country                0
# country_full           0
# country_code           0
# discipline             0
# disciplines_code       0
# events               321
# athletes               3
# coaches             1452
# athletes_codes         3
# num_athletes           3
# coaches_codes       1452
# num_coaches         1452
# dtype: int64

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">6.2) Removal or filling of missing values :<h2/>

# %%
# %%time
df_csv.dropna()  # Drills down the rows with null values
df_csv.fillna(value=0)  # Fill the missing values with 0
df_csv
# Out:
# CPU times: user 3.78 ms, sys: 0 ns, total: 3.78 ms
#
# Wall time: 3.38 ms
#                    code                        team team_gender  \
# 0     ARCMTEAM3---CHN01  People's Republic of China           M
# 1     ARCMTEAM3---COL01                    Colombia           M
# 2     ARCMTEAM3---FRA01                      France           M
# 3     ARCMTEAM3---GBR01               Great Britain           M
# 4     ARCMTEAM3---IND01                       India           M
# ...                 ...                         ...         ...
# 1693  WPOWTEAM7---GRE01                      Greece           W
# 1694  WPOWTEAM7---HUN01                     Hungary           W
# 1695  WPOWTEAM7---ITA01                       Italy           W
# 1696  WPOWTEAM7---NED01                 Netherlands           W
# 1697  WPOWTEAM7---USA01    United States of America           W
#
#             country                country_full country_code  discipline  \
# ...

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 7) Basic Operations
# <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a> <a href="#cita5" target="_blank" style="color:#b5ff46; font-size:2.5rem">[5]</a>  </h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">7.1) Aggregations (sum, mean, etc.): <h2/>

# %%
# %%time
# Assuming df_csv is already defined and loaded with your data

# Mean
media_num_athletes = df_csv['num_athletes'].mean()  # Calculate the average (mean) of the 'num_athletes' column
media_num_coaches = df_csv['num_coaches'].mean()  # Calculate the average (mean) of the 'num_coaches' column

print(f"Media de num_athletes: {media_num_athletes}")  # Print the mean of the 'num_athletes' column
print(f"Media de num_coaches: {media_num_coaches}")  # Print the mean of the 'num_coaches' column

# Median
mediana_num_athletes = df_csv['num_athletes'].median()  # Calculate the median of the 'num_athletes' column
mediana_num_coaches = df_csv['num_coaches'].median()  # Calculate the median of the 'num_coaches' column

print(f"Mediana de num_athletes: {mediana_num_athletes}")  # Print the median of the 'num_athletes' column
print(f"Mediana de num_coaches: {mediana_num_coaches}")  # Print the median of the 'num_coaches' column

# Mode
moda_num_athletes = df_csv['num_athletes'].mode()[0]  # Calculate the mode (most frequent value) of the 'num_athletes' column and take the first value
moda_num_coaches = df_csv['num_coaches'].mode()[0]  # Calculate the mode (most frequent value) of the 'num_coaches' column and take the first value

print(f"Moda de num_athletes: {moda_num_athletes}")  # Print the mode of the 'num_athletes' column
print(f"Moda de num_coaches: {moda_num_coaches}")  # Print the mode of the 'num_coaches' column
# Out:
# Media de num_athletes: 4.600589970501475
#
# Media de num_coaches: 4.365853658536586
#
# Mediana de num_athletes: 4.0
#
# Mediana de num_coaches: 4.0
#
# Moda de num_athletes: 2.0
#
# Moda de num_coaches: 3.0
#
# CPU times: user 2.85 ms, sys: 0 ns, total: 2.85 ms
#
# Wall time: 2.19 ms

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">7.2) Groupings (groupby):</h2>

# %%
# %%time
# Grouping by country and calculating the average number of athletes and coaches
promedio_por_pais = df_csv.groupby('country')[['num_athletes', 'num_coaches']].mean().reset_index()  # Groups the data by the 'country' column and calculates the mean of 'num_athletes' and 'num_coaches' for each country, then resets the index to turn the result back into a DataFrame.
print(promedio_por_pais)  # Prints the DataFrame showing the average number of athletes and coaches per country.

# Finding the event with the most participants
evento_mas_participantes = df_csv.groupby('events')['athletes'].sum().idxmax()  # Groups the data by the 'events' column, sums up the 'athletes' column for each event, and then finds the event with the maximum number of participants.
print(f"The event with the most participants is: {evento_mas_participantes}")  # Prints the event with the highest number of participants.
# Out:
#         country  num_athletes  num_coaches
#
# 0           AIN      2.000000          NaN
#
# 1       Algeria      3.000000     2.000000
#
# 2        Angola      6.000000     4.000000
#
# 3     Argentina      7.857143     6.166667
#
# 4     Australia      4.558140     4.000000
#
# ..          ...           ...          ...
#
# 99      Uruguay      8.000000     6.000000
#
# 100  Uzbekistan      8.400000     2.000000
#
# 101   Venezuela      4.000000     2.000000
#
# 102     Vietnam      2.000000          NaN
#
# 103      Zambia     12.500000     4.000000
#
#
#
# [104 rows x 3 columns]
#
# The event with the most participants is: Men's Kayak Double 500m
#
# CPU times: user 4.21 ms, sys: 1.14 ms, total: 5.35 ms
#
# Wall time: 4.62 ms

# %%
# %%time
import numpy as np #import numpy library to work with numerical data

# Assume df_csv is your DataFrame
# First, make sure that the columns 'num_athletes' and 'num_coaches' are numeric
df_csv['num_athletes'] = pd.to_numeric(df_csv['num_athletes'], errors='coerce')  # Convert the 'num_athletes' column to numeric, setting invalid parsing to NaN (not a number).
df_csv['num_coaches'] = pd.to_numeric(df_csv['num_coaches'], errors='coerce')  # Convert the 'num_coaches' column to numeric, setting invalid parsing to NaN.

# Next, calculate the proportion of athletes per coach
df_csv['athletes_per_coach'] = df_csv['num_athletes'] / df_csv['num_coaches']  # Create a new column 'athletes_per_coach' by dividing 'num_athletes' by 'num_coaches'.

# Handle cases where 'num_coaches' might be 0 to avoid division by zero
df_csv['athletes_per_coach'] = df_csv['athletes_per_coach'].replace([np.inf, -np.inf], np.nan)  # Replace infinite values (which occur if 'num_coaches' is 0) with NaN.

# Print the DataFrame to see the new column
print(df_csv[['country', 'num_athletes', 'num_coaches', 'athletes_per_coach']].head())  # Display the first few rows of the DataFrame, showing the columns 'country', 'num_athletes', 'num_coaches', and 'athletes_per_coach'.
# Out:
#          country  num_athletes  num_coaches  athletes_per_coach
#
# 0          China           3.0          NaN                 NaN
#
# 1       Colombia           3.0          NaN                 NaN
#
# 2         France           3.0          NaN                 NaN
#
# 3  Great Britain           3.0          NaN                 NaN
#
# 4          India           3.0          NaN                 NaN
#
# CPU times: user 3.08 ms, sys: 0 ns, total: 3.08 ms
#
# Wall time: 2.94 ms

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 8) Data handling <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a>  <a href="#cita5" target="_blank" style="color:#b5ff46; font-size:2.5rem">[5]</a>
# </h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">8.1) Creating new columns:</h2>

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">8.2) Apply functions to columns (apply): </h2>

# %%
# %%time

# Suppose df_csv is your DataFrame
# First, ensure that 'num_athletes' and 'num_coaches' columns are numeric
df_csv['num_athletes'] = pd.to_numeric(df_csv['num_athletes'], errors='coerce')  # Convert 'num_athletes' column to numeric, invalid parsing will be set as NaN
df_csv['num_coaches'] = pd.to_numeric(df_csv['num_coaches'], errors='coerce')  # Convert 'num_coaches' column to numeric, invalid parsing will be set as NaN

# Next, calculate the proportion of athletes per coach
df_csv['athletes_per_coach'] = df_csv['num_athletes'] / df_csv['num_coaches']  # Divide the number of athletes by the number of coaches to get the ratio

# Handle cases where num_coaches might be 0 to avoid division by zero errors
df_csv['athletes_per_coach'] = df_csv['athletes_per_coach'].replace([np.inf, -np.inf], np.nan)  # Replace infinite values with NaN

# Now, create a new column 'management_status' using a lambda function
df_csv['management_status'] = df_csv['athletes_per_coach'].apply(lambda x: 'Well managed' if x <= 10 else 'Poorly managed')  # Apply a function that labels management status based on the ratio of athletes per coach

# Print the DataFrame to see the new column
print(df_csv[['country', 'num_athletes', 'num_coaches', 'athletes_per_coach', 'management_status']].head())  # Display the first few rows of the DataFrame with selected columns
# Out:
#          country  num_athletes  num_coaches  athletes_per_coach  \
#
# 0          China           3.0          NaN                 NaN
#
# 1       Colombia           3.0          NaN                 NaN
#
# 2         France           3.0          NaN                 NaN
#
# 3  Great Britain           3.0          NaN                 NaN
#
# 4          India           3.0          NaN                 NaN
#
#
#
#   management_status
#
# 0    Poorly managed
#
# 1    Poorly managed
#
# 2    Poorly managed
#
# 3    Poorly managed
#
# 4    Poorly managed
#
# CPU times: user 3.78 ms, sys: 0 ns, total: 3.78 ms
#
# Wall time: 3.54 ms

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">8.3) Rename columns:</h2>

# %%
# %%time
# Assuming df_csv is your DataFrame
# First, ensure that the columns num_athletes and num_coaches are numeric
df_csv['num_athletes'] = pd.to_numeric(df_csv['num_athletes'], errors='coerce')
df_csv['num_coaches'] = pd.to_numeric(df_csv['num_coaches'], errors='coerce')

# Then, calculate the ratio of athletes per coach
df_csv['athletes_per_coach'] = df_csv['num_athletes'] / df_csv['num_coaches']

# Handle cases where num_coaches could be 0 to avoid division by zero
df_csv['athletes_per_coach'] = df_csv['athletes_per_coach'].replace([np.inf, -np.inf], np.nan)

# Now, create a new column 'management_status' using a lambda function
df_csv['management_status'] = df_csv['athletes_per_coach'].apply(lambda x: 'Well Managed' if x <= 10 else 'Poorly Managed')

# Renaming columns for better readability
df_csv.rename(columns={
    'code': 'team_code',
    'team': 'team_name',
    'team_gender': 'team_gender',
    'country': 'country_short',
    'country_full': 'country_full_name',
    'country_code': 'country_code',
    'discipline': 'discipline',
    'disciplines_code': 'discipline_code',
    'events': 'events',
    'athletes': 'athletes',
    'coaches': 'coaches',
    'athletes_codes': 'athletes_codes',
    'num_athletes': 'number_of_athletes',
    'coaches_codes': 'coaches_codes',
    'num_coaches': 'number_of_coaches',
    'athletes_per_coach': 'athletes_per_coach_ratio',
    'management_status': 'management_status'
}, inplace=True)

# Print the DataFrame to see the new column names
print(f'The df has the renewed columns as: {df_csv}')
# Out:
# The df has the renewed columns as:               team_code                   team_name team_gender  \
#
# 0     ARCMTEAM3---CHN01  People's Republic of China           M
#
# 1     ARCMTEAM3---COL01                    Colombia           M
#
# 2     ARCMTEAM3---FRA01                      France           M
#
# 3     ARCMTEAM3---GBR01               Great Britain           M
#
# 4     ARCMTEAM3---IND01                       India           M
#
# ...                 ...                         ...         ...
#
# 1693  WPOWTEAM7---GRE01                      Greece           W
#
# 1694  WPOWTEAM7---HUN01                     Hungary           W
#
# 1695  WPOWTEAM7---ITA01                       Italy           W
#
# 1696  WPOWTEAM7---NED01                 Netherlands           W
#
# 1697  WPOWTEAM7---USA01    United States of America           W
#
#
#
#       country_short           country_full_name country_code  discipline  \
#
# ...

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 9) DataFrame combination
# <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a>  </h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">9.1) Merge :</h2>

# %%
# %%time


# Sample DataFrame for teams
data_teams = {
    'team_code': ['T1', 'T2', 'T3'],
    'team_name': ['Team A', 'Team B', 'Team C'],
    'country_short': ['USA', 'CAN', 'AUS'],
    'number_of_athletes': [10, 15, 20],
    'number_of_coaches': [2, 3, 4]
}
df_teams = pd.DataFrame(data_teams)

print(f'df_teams >>>> \n{df_teams}')

# Sample DataFrame for countries
data_countries = {
    'country_short': ['USA', 'CAN', 'AUS', 'GBR'],
    'country_full_name': ['United States', 'Canada', 'Australia', 'United Kingdom'],
    'continent': ['North America', 'North America', 'Australia', 'Europe']
}
df_countries = pd.DataFrame(data_countries)

print(f'df_teams >>>> \n{df_countries}')
# Perform a merge operation based on the 'country_short' column
df_merged = pd.merge(df_teams, df_countries, on='country_short')

# Print the merged DataFrame
print(f'df_merged  >>>> \n{df_merged}')
# Out:
# df_teams >>>>
#
#   team_code team_name country_short  number_of_athletes  number_of_coaches
#
# 0        T1    Team A           USA                  10                  2
#
# 1        T2    Team B           CAN                  15                  3
#
# 2        T3    Team C           AUS                  20                  4
#
# df_teams >>>>
#
#   country_short country_full_name      continent
#
# 0           USA     United States  North America
#
# 1           CAN            Canada  North America
#
# 2           AUS         Australia      Australia
#
# 3           GBR    United Kingdom         Europe
#
# df_merged  >>>>
#
#   team_code team_name country_short  number_of_athletes  number_of_coaches  \
#
# 0        T1    Team A           USA                  10                  2
#
# 1        T2    Team B           CAN                  15                  3
#
# 2        T3    Team C           AUS                  20                  4
#
#
#
#   country_full_name      continent
#
# ...

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">9.2) Concat :</h2>

# %%
# %%time

# Sample DataFrame 1
data1 = {
    'team_code': ['T1', 'T2', 'T3'],
    'team_name': ['Team A', 'Team B', 'Team C'],
    'country_short': ['USA', 'CAN', 'AUS'],
    'number_of_athletes': [10, 15, 20],
    'number_of_coaches': [2, 3, 4]
}
df_a = pd.DataFrame(data1)
print(f'df_a  >>>> \n{df_a}')
# Sample DataFrame 2
data2 = {
    'team_code': ['T4', 'T5', 'T6'],
    'team_name': ['Team D', 'Team E', 'Team F'],
    'country_short': ['GBR', 'FRA', 'GER'],
    'number_of_athletes': [12, 18, 22],
    'number_of_coaches': [2, 3, 4]
}
df_b = pd.DataFrame(data2)
print(f'df_b  >>>> \n{df_b}')
# Row-wise concatenation
df_concat_rows = pd.concat([df_a, df_b], ignore_index=True)

# Print the concatenated DataFrame
print("<<<<<<<<<< Row-wise concatenation: >>>>>>>>>>>> \n")
print(df_concat_rows)
# Out:
# df_a  >>>>
#
#   team_code team_name country_short  number_of_athletes  number_of_coaches
#
# 0        T1    Team A           USA                  10                  2
#
# 1        T2    Team B           CAN                  15                  3
#
# 2        T3    Team C           AUS                  20                  4
#
# df_b  >>>>
#
#   team_code team_name country_short  number_of_athletes  number_of_coaches
#
# 0        T4    Team D           GBR                  12                  2
#
# 1        T5    Team E           FRA                  18                  3
#
# 2        T6    Team F           GER                  22                  4
#
# <<<<<<<<<< Row-wise concatenation: >>>>>>>>>>>>
#
#
#
#   team_code team_name country_short  number_of_athletes  number_of_coaches
#
# 0        T1    Team A           USA                  10                  2
#
# 1        T2    Team B           CAN                  15                  3
#
# ...

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 10) Basic visualisation with Pandas
# <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a>  <a href="#cita2" target="_blank" style="color:#b5ff46; font-size:2.5rem">[2]</a></h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">10.1) Line plot:</h2>

# %%
# %%time
import matplotlib.pyplot as plt # Import matplot library for plotting

# Suppose df_csv is your DataFrame loaded from a CSV file
# df_csv = pd.read_csv('path_to_your_file.csv')

# Select the columns you want to plot
columns_to_plot = ['number_of_athletes', 'number_of_coaches', 'athletes_per_coach_ratio']
df_selected = df_csv[columns_to_plot]

# Create the line plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

for column in columns_to_plot:
    plt.plot(df_selected.index, df_selected[column], label=column)

plt.title('Comparison of Number of Athletes, Coaches, and Athlete/Coach Ratio')
plt.xlabel('Index')  # Replace 'Index' with the appropriate label if you have a time column
plt.ylabel('Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# CPU times: user 120 ms, sys: 8.32 ms, total: 128 ms
#
# Wall time: 132 ms

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">10.2) Bar plot:</h2>

# %%
# %%time
# Select the columns you want to plot
columns_to_plot = ['number_of_athletes', 'number_of_coaches', 'athletes_per_coach_ratio']
df_selected = df_csv[columns_to_plot]

# Create the bar plot
df_selected.plot(kind='bar', figsize=(10, 6))

plt.title('Comparison of Number of Athletes, Coaches, and Athlete/Coach Ratio')
plt.xlabel('Index')  # Replace 'Index' with the appropriate label if you have a time column
plt.ylabel('Values')
plt.legend(title='Metrics')
plt.grid(axis='y')

# Show the plot
plt.show()
# Out:
# CPU times: user 7.81 s, sys: 132 ms, total: 7.95 s
#
# Wall time: 7.94 s

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">10.3) Scatter plot:</h2>

# %%
# %%time
# Select the columns you want to plot
x_column = 'number_of_athletes'
y_column = 'number_of_coaches'

# Create the scatter plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

plt.scatter(df_csv[x_column], df_csv[y_column], alpha=0.5)

plt.title('Scatter Plot of Number of Athletes vs Number of Coaches')
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()
# Out:
# CPU times: user 107 ms, sys: 0 ns, total: 107 ms
#
# Wall time: 106 ms

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 11) Data export
# <a href="#cita1" target="_blank" style="color:#b5ff46; font-size:2.5rem">[1]</a>  </h1>
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">11.1) To .csv: </h2>

# %%
# %%time
df_csv.to_csv('./Data/refactored_teams.csv', index=False) #Export DataFrame to CSV file into the specified directory
# Out:
# CPU times: user 16.2 ms, sys: 0 ns, total: 16.2 ms
#
# Wall time: 16.1 ms

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">11.2) To .xslx: </h2>

# %%
# %%time
df_csv.to_excel('./Data/equipos.xlsx', index=False) #Export DataFrame to Excel file into the specified directory
# Out:
# CPU times: user 357 ms, sys: 10.8 ms, total: 368 ms
#
# Wall time: 367 ms

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">11.3) To .parquet: </h2>

# %%
# %%time
df_csv.to_parquet('./Data/equipos.parquet', index=False) # Export DataFrame to Parquet file into the specified directory
# Out:
# CPU times: user 26 ms, sys: 12 ms, total: 38.1 ms
#
# Wall time: 37.6 ms

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 12) Practical exercises
# <a href="#cita4" target="_blank" style="color:#b5ff46; font-size:2.5rem">[4]</a> </h1>
#
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">12.1) How to filter words that contain atleast 2 vowels from a series?</h2>

# %%
# %%time
# input
ser = pd.Series(['Apple', 'Orange', 'Plan', 'Python', 'Money'])

'''
Desired Output


0     Apple
1    Orange
4     Money
dtype: object
'''

# using nested loops
vowels = list("aeiou")
list_ = []
for w in ser:
    c = 0
    for l in list(w.lower()):
        if l in vowels:
            c += 1
    if c >= 2:
        print(w)
        list_.append(w)

ser[ser.isin(list_)]

# another solution using counter

from collections import Counter
mask = ser.map(lambda x: sum([Counter(x.lower()).get(i, 0) for i in list('aeiou')]) >= 2)
ser[mask]
# Out:
# Apple
# Orange
# Money
# CPU times: user 400 ms, sys: 42.1 ms, total: 442 ms
# Wall time: 447 ms
# 0     Apple
# 1    Orange
# 4     Money
# dtype: object

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;"> 12.2)  How to reverse the rows of a dataframe?:</h2>

# %%
# %%time
# input
df_c2 = pd.DataFrame(np.arange(25).reshape(5, -1))
df_c2
# Out:
# CPU times: user 165 µs, sys: 36 µs, total: 201 µs
# Wall time: 194 µs
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24

# %%
# %%time
# Solution 1
df_c2.iloc[df.index.to_list()[::-1]]

# Solutions from the webpage
# Solution 2
df_c2.iloc[::-1, :]

# Solution 3
print(df_c2.loc[df_c2.index[::-1], :])
# Out:
#     0   1   2   3   4
# 4  20  21  22  23  24
# 3  15  16  17  18  19
# 2  10  11  12  13  14
# 1   5   6   7   8   9
# 0   0   1   2   3   4
# CPU times: user 3.45 ms, sys: 81 µs, total: 3.53 ms
# Wall time: 4.28 ms

# %% [markdown]
# <h2 style="color:#8A26BD;font-size: 2rem; border-bottom: .5rem solid #71b12c;">12.3) How to find and cap outliers from a series or dataframe column? :</h2>

# %%
# %%time
# input
ser0 = pd.Series(np.logspace(-2, 2, 30))
ser1 = ser0.copy(deep = True)
ser2 = ser0.copy(deep = True)
# Out:
# CPU times: user 546 µs, sys: 0 ns, total: 546 µs
# Wall time: 517 µs

# %%
# %%time
# Solution 1
# get the quantiles values
quantiles = np.quantile(ser0, [0.05, 0.95])
ser0

# filter ser using numpy to know where the values are below or greater than 5% or 95% and replace the values
ser0.iloc[np.where(ser0 < quantiles[0])] = quantiles[0]
ser0.iloc[np.where(ser0 > quantiles[1])] = quantiles[1]

# or we can just do
ser1[ser1 < quantiles[0]] = quantiles[0]
ser1[ser1 > quantiles[1]] = quantiles[1]

ser1

# Solution from the webpage
def cap_outliers(ser0, low_perc, high_perc):
    low, high = ser0.quantile([low_perc, high_perc])
    print(low_perc, '%ile: ', low, '|', high_perc, '%ile: ', high)
    ser0[ser0 < low] = low
    ser0[ser0 > high] = high
    return(ser)

capped_ser = cap_outliers(ser2, .05, .95)
ser2
capped_ser
# Out:
# 0.05 %ile:  0.016049294076965887 | 0.95 %ile:  63.87667222018393
# CPU times: user 6.43 ms, sys: 1.94 ms, total: 8.38 ms
# Wall time: 9.68 ms
# 0     Apple
# 1    Orange
# 2      Plan
# 3    Python
# 4     Money
# dtype: object

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 13) Small challenges to apply what has been learnt
# </h1>
# <section style="display: flex; justify-content: space-around; align-items: center; padding: 20px; background-color: #0c0a0b;">
#
#   <div style="flex: 1; margin: 10px; text-align: center;">
#     <a href="https://www.kaggle.com/learn/pandas" target="_blank">
#       <img src="https://www.kaggle.com/static/images/education/km/pandas.svg" alt="Imagen 2" style="width: 100%; max-width: 300px; border-radius: 10px; transition: transform 0.3s ease;">
#       <span style="text-decoration: none; color: #333; font-weight: bold; display: block; margin-top: 10px;">Learn Pandas by Kaggle</span>
#     </a>
#   </div>
#
#   <div style="flex: 1; margin: 10px; text-align: center;">
#     <a href="https://www.hackerrank.com/challenges/np-zeros-and-ones/problem?isFullScreen=true" target="_blank">
#       <img src="https://hrcdn.net/fcore/assets/brand/logo-new-white-green-a5cb16e0ae.svg" alt="Imagen 2" style="width: 100%; max-width: 300px; border-radius: 10px; transition: transform 0.3s ease;">
#       <span style="text-decoration: none; color: #333; font-weight: bold; display: block; margin-top: 10px;">Np zeros and ones</span>
#     </a>
#   </div>
#
# </section>

# %% [markdown]
# <h1 style="color:#0c0a0b;background-color:#71b12c;font-size: 4rem; text-align: center;padding:0.5rem;border-radius:5rem;">
#   14) 👆🤓 Further resources 👆🤓
# </h1>
#
# <section style="display: flex; justify-content: space-around; align-items: center; padding: 20px; background-color: #8db084;">
#
#   <div style="flex: 1; margin: 10px; text-align: center;">
#     <a href="https://www.datacamp.com/tutorial/benchmarking-high-performance-pandas-alternatives" target="_blank">
#       <img src="https://imgs.search.brave.com/jQtc-8vkSoEq91UcN_yGF_U2OwhUMM0Jx7M2XgTBvYg/rs:fit:500:0:0:0/g:ce/aHR0cHM6Ly9vbGQt/d2FmZmxlcy5kYXRh/Y2FtcC5jb20vbG9n/by9sb2dvbWFyay5z/dmc" alt="Imagen 1" style="width: 100%; max-width: 200px; border-radius: 10px; transition: transform 0.3s ease;">
#       <span style="text-decoration: none; color: #edf2f8; font-weight: bold; display: block; margin-top: 10px;">Benchmarking High-Performance pandas Alternatives</span>
#     </a>
#   </div>
#
#   <div style="flex: 1; margin: 10px; text-align: center;">
#     <a href="https://docs.dask.org/en/stable/gpu.html" target="_blank">
#       <img src="https://docs.dask.org/en/stable/_static/images/dask-horizontal-white.svg" alt="Imagen 2" style="width: 100%; max-width: 200px; border-radius: 10px; transition: transform 0.3s ease;">
#       <span style="text-decoration: none; color: #edf2f8; font-weight: bold; display: block; margin-top: 10px;">Scale Python with Dask on GPUs - RAPIDS.ai</span>
#     </a>
#   </div>
#
#   <div style="flex: 1; margin: 10px; text-align: center;">
#     <a href="https://www.packtpub.com/en-us/product/hands-on-data-preprocessing-in-python-9781801072137" target="_blank">
#       <img src="https://content.packt.com/_/image/original/B17397/cover_image_large.jpg" alt="Imagen 3" style="width: 100%; max-width: 200px; border-radius: 10px; transition: transform 0.3s ease;">
#       <span style="text-decoration: none; color: #edf2f8; font-weight: bold; display: block; margin-top: 10px;">Hands-On Data Preprocessing in Python</span>
#     </a>
#   </div>
#
#
#   <div style="flex: 1; margin: 10px; text-align: center;">
#     <a href="https://www.packtpub.com/en-us/product/data-engineering-with-scala-and-spark-9781804612583" target="_blank">
#       <img src="https://content.packt.com/_/image/original/B18992/cover_image_large.jpg" alt="Imagen 3" style="width: 100%; max-width: 200px; border-radius: 10px; transition: transform 0.3s ease;">
#       <span style="text-decoration: none; color: #edf2f8; font-weight: bold; display: block; margin-top: 10px;">Data Engineering with Scala and Spark</span>
#     </a>
#   </div>
#
#   <div style="flex: 1; margin: 10px; text-align: center;">
#     <a href="https://spark.apache.org/docs/latest/sql-performance-tuning.html" target="_blank">
#       <img src="https://imgs.search.brave.com/Ti2mGl3n5NdMvMQmvDKSrBRtKItCUV5-UnP4279zQ4g/rs:fit:500:0:0:0/g:ce/aHR0cHM6Ly91cGxv/YWQud2lraW1lZGlh/Lm9yZy93aWtpcGVk/aWEvY29tbW9ucy9m/L2YzL0FwYWNoZV9T/cGFya19sb2dvLnN2/Zw" alt="Imagen 3" style="width: 100%; max-width: 200px; border-radius: 10px; transition: transform 0.3s ease;">
#       <span style="text-decoration: none; color: #edf2f8; font-weight: bold; display: block; margin-top: 10px;">Performance Tuning in Spark</span>
#     </a>
#   </div>
#
#
# </section>

# %% [markdown]
# </br>
# </br>
# </br>
# <h3 style="color:#0c0a0b;background-color:#71b12c;font-size: 2.5rem; text-align: center;padding:0.5rem;border-radius:5rem;"> 📑 References 📑</h3>
#
#
#
#
#
# <ol>
#   <li id="cita1" style="color:#b5ff46; font-size:2rem">Pandas Development Team. (2024). Pandas 2.2 Documentation. Retrieved from ht
#      <a href="https://pandas.pydata.org/docs/reference/index.html" target="_blank">https://pandas.pydata.org/docs/reference/index.html</a>
#  </li>
#
#   <li id="cita2" style="color:#b5ff46; font-size:2rem">Matplotlib Developers. (2024). Matplotlib 3.9 Documentation. Retrieved from
#       <a href="https://matplotlib.org/stable/gallery/index.html" target="_blank">https://matplotlib.org/stable/gallery/index.html</a>
#  </li>
#
#   <li id="cita3" style="color:#b5ff46; font-size:2rem">Syed Sajeel Haider. (2024). Paris Olympics 2024 Games Dataset (updated daily). Kaggle.com. Retrieved from
#       <a href="https://www.kaggle.com/datasets/sajkazmi/paris-olympics-2024-games-dataset-updated-daily" target="_blank">https://www.kaggle.com/datasets/sajkazmi/paris-olympics-2024-games-dataset-updated-daily</a>
#  </li>
#     <li id="cita4" style="color:#b5ff46; font-size:2rem">icarofreire. (2020, April 2). Pandas 24 useful exercises with solutions. Kaggle.com. Retrieved from
#       <a href="https://www.kaggle.com/code/icarofreire/pandas-24-useful-exercises-with-solutions" target="_blank">https://www.kaggle.com/code/icarofreire/pandas-24-useful-exercises-with-solutions</a>
#  </li>
#
#   <li id="cita5" style="color:#b5ff46; font-size:2rem">NumPy. (2024). NumPy Reference — NumPy v2.0.0 Manual. Retrieved from
#       <a href="https://numpy.org/doc/stable/release.html" target="_blank">https://numpy.org/doc/stable/release.html</a>
#  </li>
# </ol>
